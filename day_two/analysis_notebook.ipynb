# %%
import json

triplets = json.load(open("triplets.json", "r"))

# %%
len(triplets)
# Out:
# 358

# %%
[3,4,5] in triplets
# Out:
# True

# %%
triplets
# Out:
# [[888, 259, 925.0],
#  [135, 72, 153.0],
#  [210, 200, 290.0],
#  [375, 200, 425.0],
#  [510, 272, 578.0],
#  [188, 141, 235.0],
#  [490, 168, 518.0],
#  [75, 100, 125.0],
#  [33, 180, 183.0],
#  [372, 279, 465.0],
#  [980, 336, 1036.0],
#  [556, 417, 695.0],
#  [552, 736, 920.0],
#  [943, 576, 1105.0],
#  [96, 247, 265.0],
#  [69, 92, 115.0],
#  [135, 324, 351.0],
#  [915, 488, 1037.0],
#  [560, 588, 812.0],
#  [420, 400, 580.0],
#  [396, 80, 404.0],
#  [121, 660, 671.0],
#  [171, 760, 779.0],
#  [72, 54, 90.0],
#  [918, 440, 1018.0],
#  [117, 44, 125.0],
#  [300, 455, 545.0],
#  [256, 192, 320.0],
#  [285, 684, 741.0],
#  [170, 264, 314.0],
#  [952, 186, 970.0],
#  [328, 615, 697.0],
#  [513, 420, 663.0],
#  [440, 330, 550.0],
#  [351, 132, 375.0],
#  [989, 660, 1189.0],
#  [114, 152, 190.0],
#  [160, 792, 808.0],
#  [360, 675, 765.0],
#  [417, 556, 695.0],
#  [585, 220, 625.0],
#  [40, 30, 50.0],
#  [330, 440, 550.0],
#  [320, 462, 562.0],
#  [720, 300, 780.0],
# ...

# %%
656**2 + 492**2
# Out:
# 672400
